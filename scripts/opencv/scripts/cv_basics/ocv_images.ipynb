# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2


# pic = Image.open('../../data/00-puppy.jpg')

# %%
# img = np.zeros((512,512,3),np.int8)
# plt.imshow(img)

# %%
img = cv2.imread('../../data/00-puppy.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
# MATPLOTLIB : RGB
# OCV : BGR
fix_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_image)

# %%
img = cv2.imread('../../data/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)
img.shape
# Out:
# (1300, 1950)

# %%
img.max(),img.min()
# Out:
# (209, 1)

# %%
# Note actual image size 1350,1950 -> 400,100
# Pay attention to ordering
new_image = cv2.resize(fix_image,(1000,400))
plt.imshow(new_image)

# %%
fix_height = 0.5
fix_width = 0.5
new_image2 = cv2.resize(fix_image,(0,0),fix_image,fix_width,fix_height)
plt.imshow(new_image2)

# %%
new_image3 = cv2.flip(fix_image,-1)
plt.imshow(new_image3)

# %%
type(new_image3)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('../../data/flip_dog.jpeg',new_image3)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_image)
